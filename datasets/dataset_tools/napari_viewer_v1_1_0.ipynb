# %%
import napari
import nibabel as nib
import pandas as pd

# %% [markdown]
# ## STS-Tooth

# %%
# STS-Tooth
#img = nib.load("./STS-Tooth/Integrity_L_001.nii.gz")
#img = nib.load("./STS-Tooth/Integrity_L_010.nii.gz")
#img = nib.load("./STS-Tooth/ROI_L_001.nii.gz")

# unlabeled
#img = nib.load("D:/chewing_gum/DATASETS/RAW/STS-Tooth/SD-Tooth/STS-3D-Tooth/Integrity/Labeled/Image/Integrity_L_001.nii.gz")
#img = nib.load("D:/chewing_gum/DATASETS/RAW/STS-Tooth/SD-Tooth/STS-3D-Tooth/Integrity/Unlabeled/Image/Integrity_U_001.nii.gz")
#img = nib.load("D:/chewing_gum/DATASETS/RAW/STS-Tooth/SD-Tooth/STS-3D-Tooth/Integrity/Labeled/Mask/Integrity_L_001.nii.gz")
#img = nib.load(r"D:\chewing_gum\DATASETS\RAW\3D_multimodal_dental_dataset_based_on_CBCT_and_oral_scans\177\177_cbct\177_cbct.nii.gz")
#img = nib.load(r"D:\chewing_gum\DATASETS\RAW\3D_multimodal_dental_dataset_based_on_CBCT_and_oral_scans\179\179_cbct\179_cbct.nii.gz")
img = nib.load(r"D:\chewing_gum\DATASETS\RAW\3D_multimodal_dental_dataset_based_on_CBCT_and_oral_scans\300\300_cbct\300_cbct.nii.gz")


# labeled
#img = nib.load(r"D:\chewing_gum\DATASETS\RAW\STS-Tooth\SD-Tooth\STS-3D-Tooth\Integrity\Labeled\Image\Integrity_L_007.nii.gz")

# %%
voxel_size = img.header.get_zooms()
print(voxel_size)

# %%
shape = img.shape
print(shape)

# %%
# 3D View

data = img.get_fdata()

viewer = napari.Viewer(ndisplay=3)
viewer.add_image(data)

napari.run()

# %% [markdown]
# ## ToothFairy3

# %%
# ToothFairy3
#img = nib.load("./ToothFairy3/ToothFairy3F_001.nii.gz")
#img = nib.load("./ToothFairy3/ToothFairy3F_001_0000.nii.gz")
#img = nib.load("D:/chewing_gum/DATASETS/RAW/ToothFairy3/imagesTr/ToothFairy3F_001_0000.nii.gz")

#img = nib.load("D:/chewing_gum/DATASETS/RAW/ToothFairy3/labelsTr/ToothFairy3F_001.nii.gz")
#img = nib.load(r"D:\chewing_gum\DATASETS\RAW\ToothFairy3\imagesTr\ToothFairy3F_004_0000.nii.gz")
#img = nib.load(r"D:\chewing_gum\DATASETS\RAW\ToothFairy3\imagesTr\ToothFairy3P_019_0000.nii.gz")
#img = nib.load(r"D:\chewing_gum\DATASETS\RAW\ToothFairy3\imagesTr\ToothFairy3P_259_0000.nii.gz")
img = nib.load(r"D:\chewing_gum\DATASETS\RAW\ToothFairy3\imagesTr\ToothFairy3P_333_0000.nii.gz")

# %%
voxel_size = img.header.get_zooms()
print(voxel_size)

# %%
shape = img.shape
print(shape)

# %%
# 3D View

data = img.get_fdata()

viewer = napari.Viewer(ndisplay=3)
viewer.add_image(data)

napari.run()

# %% [markdown]
# ## MMDental

# %%
# MMDental
#img = nib.load("./MMDental/658.nii.gz")
#img = nib.load("./MMDental/3.nii.gz")
#img = nib.load("D:/chewing_gum/DATASETS/RAW/MMDental/1/1.nii.gz")
#img = nib.load("D:/chewing_gum/DATASETS/RAW/MMDental/3/3.nii.gz")
#img = nib.load(r"D:\chewing_gum\DATASETS\RAW\MMDental\401\401.nii.gz")
img = nib.load(r"D:\chewing_gum\DATASETS\RAW\MMDental\555\555.nii.gz")

#img = nib.load("D:/chewing_gum/DATASETS/RAW/MMDental/658/658.nii.gz")

# %%
voxel_size = img.header.get_zooms()
print(voxel_size)

# %%
shape = img.shape
print(shape)

# %%
df_mmdental = pd.read_csv('D:/chewing_gum/DATASETS/RAW/MMDental/medical_records.csv')

df_mmdental.columns

# %%
df_mmdental['Age'].min()

# %%
df_mmdental['Age'].max()

# %%
df_mmdental['Age'].hist(bins=100)

# %%
df_mmdental.head(1)

# %%
df_mmdental['Filename'].nunique()

# %%
df_mmdental.loc[df_mmdental['Age'] < 18.0].shape

# %%
# 3D View

data = img.get_fdata()

viewer = napari.Viewer(ndisplay=3)
viewer.add_image(data)

napari.run()

# %% [markdown]
# ## PMCanalSeg

# %%
# PMCanalSeg
#img = nib.load("D:/chewing_gum/DATASETS/RAW/PMCanalSeg/dataverse_files/skull/Patient_005/image.nii.gz")
#img = nib.load(r"D:\chewing_gum\DATASETS\RAW\PMCanalSeg\dataverse_files\skull\Patient_001\image.nii.gz")
#img = nib.load(r"D:\chewing_gum\DATASETS\RAW\PMCanalSeg\dataverse_files\skull\Patient_002\image.nii.gz")
img = nib.load(r"D:\chewing_gum\DATASETS\RAW\PMCanalSeg\dataverse_files\skull\Patient_044\image.nii.gz")

# %%
voxel_size = img.header.get_zooms()
print(voxel_size)

# %%
shape = img.shape
print(shape)

# %%
# 3D View

data = img.get_fdata()

viewer = napari.Viewer(ndisplay=3)
viewer.add_image(data)

napari.run()

# %% [markdown]
# ## DentalVoxel

# %%
# DentalVoxel
#img = nib.load("./DentalVoxel/label0001.nii.gz")
#img = nib.load("./DentalVoxel/img0001.nii.gz")

#img = nib.load("D:/chewing_gum/DATASETS/RAW/DentVoxel/DentVoxel_Dataset/label/label0001.nii.gz")
#img = nib.load("D:/chewing_gum/DATASETS/RAW/DentVoxel/DentVoxel_Dataset/image/img0001.nii.gz")
img = nib.load(r"D:\chewing_gum\DATASETS\RAW\DentVoxel\DentVoxel_Dataset\image\img0069.nii.gz")
#img = nib.load(r"D:\chewing_gum\DATASETS\RAW\DentVoxel\DentVoxel_Dataset\image\img0085.nii.gz")
#img = nib.load(r"D:\chewing_gum\DATASETS\RAW\DentVoxel\DentVoxel_Dataset\image\img0105.nii.gz")

# %%
voxel_size = img.header.get_zooms()
print(voxel_size)

# %%
shape = img.shape
print(shape)

# %%
# 3D View

data = img.get_fdata()

viewer = napari.Viewer(ndisplay=3)
viewer.add_image(data)

napari.run()

# %% [markdown]
# ## Adults

# %%
# Adults
#img = nib.load("./Adults/CG.ct.nii.gz")

# annotated
#img = nib.load("D:/chewing_gum/DATASETS/RAW/Adults’ dental cone beam computed tomography images dataset for detecting and classifying missing teeth/Dataset/Dataset/annotated/annotated_nifti/M04/M04_#myct##type=CT#_20201104144746_-207105093.nii.gz")
#img = nib.load(r"D:\chewing_gum\DATASETS\RAW\Adults’ dental cone beam computed tomography images dataset for detecting and classifying missing teeth\Dataset\Dataset\annotated\annotated_nifti\K05\K05_[QuantumIQ_9,520]_20210606102517_262261554.nii.gz")
#img = nib.load(r"D:\chewing_gum\DATASETS\RAW\Adults’ dental cone beam computed tomography images dataset for detecting and classifying missing teeth\Dataset\Dataset\annotated\annotated_nifti\M62\M62_#myct##type=CT#_20220409170405_-390370593.nii.gz")

# unannotated
# quantum
#img = nib.load(r"D:\chewing_gum\DATASETS\RAW\Adults’ dental cone beam computed tomography images dataset for detecting and classifying missing teeth\Dataset\Dataset\unannotated\unannotated_nifti\K30\K30_[QuantumIQ_9,392]_20220429134206_1327624462.nii.gz")
# myct
#img = nib.load(r"D:\chewing_gum\DATASETS\RAW\Adults’ dental cone beam computed tomography images dataset for detecting and classifying missing teeth\Dataset\Dataset\unannotated\unannotated_nifti\M63\M63_#myct##type=CT#_20220824161034_-1664650118.nii.gz")
# N
img = nib.load(r"D:\chewing_gum\DATASETS\RAW\Adults’ dental cone beam computed tomography images dataset for detecting and classifying missing teeth\Dataset\Dataset\unannotated\unannotated_nifti\N13\N13_Full_20220324141347_1.nii.gz")

#img = nib.load("D:/chewing_gum/DATASETS/RAW/Adults’ dental cone beam computed tomography images dataset for detecting and classifying missing teeth/Dataset/Dataset/unannotated/unannotated_nifti/M64/M64_#myct##type=CT#_20201104093438_-1825116866.nii.gz")

# %%
voxel_size = img.header.get_zooms()
print(voxel_size)

# %%
shape = img.shape
print(shape)

# %%
# 3D View

data = img.get_fdata()

viewer = napari.Viewer(ndisplay=3)
viewer.add_image(data)

napari.run()

# %% [markdown]
# ## Midpalatal suture

# %%
# A dataset of midpalatal suture maturation stage in Cone-Beam computed tomography
#img = nib.load(r"D:\chewing_gum\DATASETS\RAW\A dataset of midpalatal suture maturation stage in Cone-Beam computed tomography\100.nii.gz")
#img = nib.load(r"D:\chewing_gum\DATASETS\RAW\A dataset of midpalatal suture maturation stage in Cone-Beam computed tomography\106.nii.gz")
#img = nib.load(r"D:\chewing_gum\DATASETS\RAW\A dataset of midpalatal suture maturation stage in Cone-Beam computed tomography\28.nii.gz")
img = nib.load(r"D:\chewing_gum\DATASETS\RAW\A dataset of midpalatal suture maturation stage in Cone-Beam computed tomography\195.nii.gz")

#img = nib.load("D:/chewing_gum/DATASETS/RAW/A dataset of midpalatal suture maturation stage in Cone-Beam computed tomography/332.nii.gz")

# %%
voxel_size = img.header.get_zooms()
print(voxel_size)

# %%
shape = img.shape
print(shape)

# %%
import pandas as pd
df = pd.read_csv("D:/chewing_gum/DATASETS/RAW/A dataset of midpalatal suture maturation stage in Cone-Beam computed tomography/Tabular_Data.csv")

# %%
df.columns

# %%
df.loc[df['Age (4-24)'] > 16].shape

# %%
df['Age (4-24)'].min()

# %%
df['Age (4-24)'].max()

# %%
# 3D View

data = img.get_fdata()

viewer = napari.Viewer(ndisplay=3)
viewer.add_image(data)

napari.run()

# %% [markdown]
# ## 3D_multimodal

# %%
# 3D_multimodal
#img = nib.load("D:/chewing_gum/DATASETS/RAW/3D_multimodal_dental_dataset_based_on_CBCT_and_oral_scans/001/001_cbct/001_cbct.nii.gz")
#img = nib.load(r"D:\chewing_gum\DATASETS\RAW\3D_multimodal_dental_dataset_based_on_CBCT_and_oral_scans\017\017_cbct\017_cbct.nii.gz")
img = nib.load(r"D:\chewing_gum\DATASETS\RAW\3D_multimodal_dental_dataset_based_on_CBCT_and_oral_scans\085\085_cbct\085_cbct.nii.gz")

# %%
voxel_size = img.header.get_zooms()
print(voxel_size)

# %%
shape = img.shape
print(shape)

# %%
# 3D View

data = img.get_fdata()

viewer = napari.Viewer(ndisplay=3)
viewer.add_image(data)

napari.run()
