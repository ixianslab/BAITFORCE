# %%
import pandas as pd

pd.set_option('display.max_colwidth', 1500)

pd.set_option('display.expand_frame_repr', False)

# %%
datset_df = pd.DataFrame(
    {'3D multimodal CBCT': [300, [0.249, 0.249, 0.25]          , (604, 604, 412), '18-29', 2024, 'CC_BY_4.0'  , '--'           , 'patients between 18-29', 'adequate'],
     'Midpalatal suture':  [263, [0.25, 0.25, 0.25]            , (640, 640, 528), '18-25', 2025, 'CC_BY_4.0'  , '--'           , 'patients between 4-25, 263 CBCT´s over 18', 'adequate'],
     'Adults':             [158, [0.265751, 0.265751, 0.2514]  , (480, 480, 320), '--'   , 2026, 'CC_BY_4.0'  , '--'           , 'no age data', 'adequate'],
     'DentVoxel':          [100, [0.3, 0.3, 0.3]               , (440, 440, 344), '--'   , 2026, 'CC_BY_4.0'  , '--'           , '10 labeled and 231 unlabeled data, artifacts', 'adequate'],
     'PMCanalSeg':         [191, [0.5703125, 0.5703125, 0.3125], (512, 512, 948), '--'   , 2025, 'CC0 1.0'    , 'China'        , '75 male, 119 female', 'partially adequate'],
     'MMDental':           [403, [0.25, 0.25, 0.25]            , (640, 640, 400), '--'   , 2025, 'CC0 1.0'    , 'China'        , '403 CBCT´s, patients between 5-86, artifacts, 257 patients contribute medical records', 'adequate'],
     'ToothFairy3':        [532, [0.3, 0.3, 0.3]               , (512, 512, 262), '--'   , 2024, 'CC-BY-NC-SA', '--'           , '532 CBCT´s with segmentations, artifacts, some images are cropped', 'adequate'],
     'STSTooth':           [241, [0.25, 0.25, 0.25]            , (512, 512, 400), '--'   , 2024, 'CC_BY_4.0'  , 'China/England', 'contains 10 labeled and 231 unlabeled scans', 'adequate'],
        },
    index=pd.Index(['CBCT scans',
                    'vox_size',
                    'vox_dim',
                    'Age',
                    'Year',
                    'License',
                    'Country',
                    'Remarks',
                    'Evaluation'])
    )

# %%
datset_df
# Out:
#                 3D multimodal CBCT                          Midpalatal suture                        Adults                                     DentVoxel                      PMCanalSeg                                                                               MMDental                    ToothFairy3                                     STSTooth
# CBCT scans                     300                                        263                           158                                           100                             191                                                                                    403                            532                                          241
# ...

# %%
datset_df.loc['CBCT scans', :].sum()
# Out:
# 2188

# %%
datset_df.loc['CBCT scans', ['3D multimodal CBCT', 'Midpalatal suture', 'Adults', 'DentVoxel', 'MMDental', 'ToothFairy3', 'STSTooth']].sum()
# Out:
# 1997

# %%
import dataframe_image as dfi
import matplotlib.pyplot as plt

plt.rcParams["figure.dpi"] = 900            # Auflösung erhöhen
plt.rcParams["figure.figsize"] = (12, 6)

dfi.export(datset_df.T, "dataset2.png", table_conversion='matplotlib')
# Out:
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt


# Figure erstellen
fig, ax = plt.subplots(figsize=(6,2))  # Größe anpassen
ax.axis('tight')
ax.axis('off')

# Tabelle plotten
tbl = ax.table(cellText=datset_df.values,
               colLabels=datset_df.columns,
               cellLoc='center',
               loc='center')

# Bild speichern
plt.savefig('tabelle.png', dpi=300, bbox_inches='tight')
plt.show()
