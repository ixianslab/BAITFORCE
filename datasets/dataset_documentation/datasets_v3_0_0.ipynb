# %%
import pandas as pd

pd.set_option('display.max_colwidth', None)

pd.set_option('display.expand_frame_repr', False)

pd.set_option('display.width', 2000)

# %%
datset_df = pd.DataFrame(
    {'3D multimodal CBCT': ['300 scans; AGE:18-29y', 'https://figshare.com/articles/dataset/_b_3D_multimodal_dental_dataset_based_on_CBCT_and_oral_scan_b_/26965903'],
     'Midpalatal suture':  ['600 scans, 259 Male, 341 Female; AGE:4-25, 263 scans > 18y; anonyimzed data; informed consent; Tianjin,China; collected 2020-2025; SCANNER:KaVo 3D eXam; medical records present', 'https://www.nature.com/articles/s41597-026-06778-3'],
     'Adults':             ['158 scans; no age data; annotated dataset; anonymized data', 'https://www.nature.com/articles/s41597-026-07156-9'],
     'DentVoxel':          ['10 labeled, 231 unlabeled scans; artifacts present; no patient data', 'https://doi.org/10.6084/m9.figshare.31239889'],
     'PMCanalSeg':         ['75 male, 119 female; anonymized data (GDPR) and (HIPAA); informed consent; collected 2021-2023; AGE:17-35y; SCANNER:Neusoft Medical Systems; medical records present; spine excluded with 3D Slicer; bone mask was then element-wise multiplied with the original CBCT volume to suppress soft tissue and cervical vertebrae', 'https://www.nature.com/articles/s41597-026-06620-w'],
     'MMDental':           ['403 scans; AGE:5-86; artifacts present; 257 patients contribute medical records; wide range of dental conditions and demographics; anonymized data; informed consent; SCANNERS: HiRes 3D-Plus (Beijing Langshi Instrument Co., Ltd.), Oral and Maxillofacial CBCT Equipment (Changzhou Boen Zhongding Medical Technology Co., Ltd.)', 'https://www.nature.com/articles/s41597-025-05398-7'],
     'ToothFairy3':        ['532 scans; segmentations; artifacts present; some images are cropped; Affidea Center, a pan-European healthcare group located in Modena, est data originates from the Department of Oral and Maxillofacial Surgery at Radboud University Medical Centre, Nijmegen; anonymized data; 59.02% Female (59.82% in the training set, 52.00% in the test set); collected 2019-2020, AGE:10-100 Modes at (20-30],(60-70] training set and (50-70] test set', 'https://ieeexplore.ieee.org/document/10816445'],
     'STSTooth':           ['10 labeled,231 unlabeled scans; 422 patients; AGE:10-82y; SCANNER:HiRes3D-Plus device by Changzhou Boneng Zhongding Medical Technology; anonymized data', 'https://www.nature.com/articles/s41597-024-04306-9#Abs1'],
        },
    index=pd.Index(['Remarks',
                    'Source'])
    )

# %%
# datset_df.style.set_properties(subset=['PMCanalSeg'], **{
#     'white-space': 'pre-wrap'
# })

# %%
datset_df
# Out:
#                 3D multimodal CBCT                          Midpalatal suture                                                                                           Adults                                                                                                            DentVoxel                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        MMDental                                                   
# ...

# %%
import pandas as pd

datset_df = pd.DataFrame(
{
'3D multimodal CBCT': [
    "Age: 18–29",
    "adequate"
],
'Midpalatal suture': [
    "Age: 4–25; 263 CBCTs",
    "adequate"
],
'Adults': [
    "No age data; annotated; 85 patients (missing teeth sites)",
    "adequate"
],
'DentVoxel': [
    "10 labeled; 231 unlabeled; artifacts; no patient data; DOI source",
    "adequate"
],
'PMCanalSeg': [
    "75M/119F; age 17–35; 2021–2023; Neusoft scanner; GDPR/HIPAA; anonymized; spine removed; bone-only",
    "partially adequate"
],
'MMDental': [
    "403 CBCTs; age 5–86; 257 records; diverse demographics; consent incl. minors; HiRes 3D-Plus; Nature source",
    "adequate"
],
'ToothFairy3': [
    "532 CBCTs; segmented; 2019–2020; Modena + Radboud; anonymized; age 10–100; ~59% female; IEEE source",
    "adequate"
],
'STSTooth': [
    "10 labeled; 231 unlabeled; 422 patients; age 10–82; HiRes3D-Plus; anonymized; academic use; Nature source",
    "adequate"
],
},
index=["Remarks", "Evaluation"]
)

datset_df
# Out:
#            3D multimodal CBCT     Midpalatal suture                                                     Adults                                                          DentVoxel                                                                                         PMCanalSeg                                                                                                    MMDental                                                                                          ToothFairy3                                                                                                   STSTooth
# ...

# %%
import dataframe_image as dfi
import matplotlib.pyplot as plt

plt.rcParams["figure.dpi"] = 900            # Auflösung erhöhen
plt.rcParams["figure.figsize"] = (12, 6)
plt.rcParams['font.family'] = 'DejaVu Sans'

dfi.export(datset_df.T, "dataset3.png", table_conversion='matplotlib')
# Out:
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# ...

# %%
dfi.export(
    datset_df.T,
    "dataset4.png",
    table_conversion="html"
)
# Out:
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt


# Figure erstellen
fig, ax = plt.subplots(figsize=(6,2))  # Größe anpassen
ax.axis('tight')
ax.axis('off')

# Tabelle plotten
tbl = ax.table(cellText=datset_df.values,
               colLabels=datset_df.columns,
               cellLoc='center',
               loc='center')

# Bild speichern
plt.savefig('tabelle.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
import pandas as pd

pd.set_option('display.width', 2000)
pd.set_option('display.expand_frame_repr', False)
pd.set_option('display.max_colwidth', None)

# %%
datset_df.style.set_properties(**{
    'white-space': 'pre-wrap',
    'text-align': 'left'
})
# Out:
# <style type="text/css">
# #T_6ceac_row0_col0, #T_6ceac_row0_col1, #T_6ceac_row0_col2, #T_6ceac_row0_col3, #T_6ceac_row0_col4, #T_6ceac_row0_col5, #T_6ceac_row0_col6, #T_6ceac_row0_col7, #T_6ceac_row1_col0, #T_6ceac_row1_col1, #T_6ceac_row1_col2, #T_6ceac_row1_col3, #T_6ceac_row1_col4, #T_6ceac_row1_col5, #T_6ceac_row1_col6, #T_6ceac_row1_col7 {
#   white-space: pre-wrap;
#   text-align: left;
# }
# </style>
# <table id="T_6ceac">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6ceac_level0_col0" class="col_heading level0 col0" >3D multimodal CBCT</th>
#       <th id="T_6ceac_level0_col1" class="col_heading level0 col1" >Midpalatal suture</th>
#       <th id="T_6ceac_level0_col2" class="col_heading level0 col2" >Adults</th>
#       <th id="T_6ceac_level0_col3" class="col_heading level0 col3" >DentVoxel</th>
#       <th id="T_6ceac_level0_col4" class="col_heading level0 col4" >PMCanalSeg</th>
# ...

# %%
import pandas as pd

datset_df = pd.DataFrame(
{
'3D multimodal CBCT': [
    "• patients between 18–29",
    "adequate"
],
'Midpalatal suture': [
    "• patients between 4–25\n"
    "• 263 CBCTs over 18",
    "adequate"
],
'Adults': [
    "• no age data\n"
    "• annotated dataset\n"
    "• 85 patients (missing teeth sites)",
    "adequate"
],
'DentVoxel': [
    "• 10 labeled, 231 unlabeled\n"
    "• artifacts present\n"
    "• no patient data\n"
    "• SOURCE: doi link",
    "adequate"
],
'PMCanalSeg': [
    "• 75 male, 119 female\n"
    "• age: 17–35\n"
    "• collection: 2021–2023\n"
    "• anonymized (GDPR, HIPAA)\n"
    "• informed consent obtained\n"
    "• randomized IDs, DICOM cleaned\n"
    "• Neusoft scanner\n"
    "• spine removed (3D Slicer)\n"
    "• only craniofacial bone retained",
    "partially adequate"
],
'MMDental': [
    "• 403 CBCTs\n"
    "• age: 5–86\n"
    "• artifacts present\n"
    "• 257 patients with records\n"
    "• diverse conditions & demographics\n"
    "• informed consent (incl. minors via guardians)\n"
    "• scanners: HiRes 3D-Plus, CBCT Equipment\n"
    "• SOURCE: Nature link",
    "adequate"
],
'ToothFairy3': [
    "• 532 CBCTs with segmentations\n"
    "• artifacts, some cropped\n"
    "• data from Modena & Radboud UMC\n"
    "• anonymized\n"
    "• metadata: gender, age, scan year\n"
    "• 59% female\n"
    "• scans: 2019–2020\n"
    "• age range: 10–100\n"
    "• peaks: 20–30, 50–70\n"
    "• SOURCE: IEEE link",
    "adequate"
],
'STSTooth': [
    "• 10 labeled, 231 unlabeled scans\n"
    "• 422 patients\n"
    "• age: 10–82\n"
    "• HiRes3D-Plus device\n"
    "• anonymized medical data\n"
    "• consent for academic use\n"
    "• headers removed (privacy)\n"
    "• SOURCE: Nature link",
    "adequate"
],
},
index=pd.Index(['Remarks','Evaluation'])
)

# %%
datset_df.style.set_properties(**{'white-space': 'pre-wrap'})
# Out:
# <style type="text/css">
# #T_6618f_row0_col0, #T_6618f_row0_col1, #T_6618f_row0_col2, #T_6618f_row0_col3, #T_6618f_row0_col4, #T_6618f_row0_col5, #T_6618f_row0_col6, #T_6618f_row0_col7, #T_6618f_row1_col0, #T_6618f_row1_col1, #T_6618f_row1_col2, #T_6618f_row1_col3, #T_6618f_row1_col4, #T_6618f_row1_col5, #T_6618f_row1_col6, #T_6618f_row1_col7 {
#   white-space: pre-wrap;
# }
# </style>
# <table id="T_6618f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6618f_level0_col0" class="col_heading level0 col0" >3D multimodal CBCT</th>
#       <th id="T_6618f_level0_col1" class="col_heading level0 col1" >Midpalatal suture</th>
#       <th id="T_6618f_level0_col2" class="col_heading level0 col2" >Adults</th>
#       <th id="T_6618f_level0_col3" class="col_heading level0 col3" >DentVoxel</th>
#       <th id="T_6618f_level0_col4" class="col_heading level0 col4" >PMCanalSeg</th>
# ...
